# %% [markdown]
# # Strat with EDA so we should import librarie's

# %%
import os 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Now we will import the Data csvfile
cars = pd.read_csv('car_price_prediction.csv')
cars.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
## to know the shape of data

# %%
cars.shape
# Out:
# (19237, 18)

# %%
## to see the all informations about this data

cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
## To se the describtion of the data

# %%
cars.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
## Chek if we had a dubs values

# %%
cars.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19232    False
# 19233    False
# 19234    False
# 19235    False
# 19236    False
# Length: 19237, dtype: bool

# %%
## to know the types

# %%
cars.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %% [markdown]
# ### for Cleaning we will use some fuction's (( isnull ))

# %%
cars.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
## we not find null datat ### But if we get some data it's null
## we will use this code 

###########################################################
##  cars['column name'].fillna(cars['column name'].mean(), inplace = True)

# %%
cars['Manufacturer'].value_counts()
# Out:
# HYUNDAI          3769
# TOYOTA           3662
# MERCEDES-BENZ    2076
# FORD             1111
# CHEVROLET        1069
#                  ...
# TESLA               1
# PONTIAC             1
# SATURN              1
# ASTON MARTIN        1
# GREATWALL           1
# Name: Manufacturer, Length: 65, dtype: int64

# %%
## for filtering

# %%
cars.head(3)
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2

# %%
cars[cars['Price'] > 20000]
# Out:
#              ID  Price  Levy   Manufacturer     Model  Prod. year Category  \
# 5      45802912  39493   891        HYUNDAI  Santa FE        2016     Jeep
# 9      45756839  26657     -          LEXUS    RX 350        2007     Jeep
# 14     45732604  59464   891        HYUNDAI  Santa FE        2016     Jeep
# 17     45797221  28382   810        HYUNDAI   Elantra        2016    Sedan
# 21     45168471  20698   586         TOYOTA     Prius        2012    Sedan
# ...         ...    ...   ...            ...       ...         ...      ...
# 19211  45802856  50037   891        HYUNDAI  Santa FE        2016     Jeep
# 19216  45784464  37633  1249         TOYOTA     RAV 4        2017     Jeep
# 19217  45804344  26017  1624          LEXUS    ES 300        2009    Sedan
# 19227  45769427  29793  1053  MERCEDES-BENZ     E 350        2014    Sedan
# 19234  45804997  26108   836        HYUNDAI    Tucson        2010     Jeep
#
# ...
